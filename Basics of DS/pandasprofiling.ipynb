# %% [markdown]
# # Pandas Profiling

# %%
# !pip install ydata-profiling
# Out:
# Collecting ydata-profiling
#   Using cached ydata_profiling-4.18.1-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: scipy<1.17,>=1.8 in d:\machine learning\myenv\lib\site-packages (from ydata-profiling) (1.16.3)
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.5 in d:\machine learning\myenv\lib\site-packages (from ydata-profiling) (2.3.3)
# Collecting matplotlib<=3.10,>=3.5 (from ydata-profiling)
#   Using cached matplotlib-3.10.0-cp313-cp313-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: pydantic<3,>=2 in d:\machine learning\myenv\lib\site-packages (from ydata-profiling) (2.12.5)
# Requirement already satisfied: PyYAML<6.1,>=6.0.3 in d:\machine learning\myenv\lib\site-packages (from ydata-profiling) (6.0.3)
# Requirement already satisfied: jinja2<3.2,>=3.1.6 in d:\machine learning\myenv\lib\site-packages (from ydata-profiling) (3.1.6)
# Collecting visions<0.8.2,>=0.7.5 (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling)
#   Using cached visions-0.8.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy<2.4,>=1.22 in d:\machine learning\myenv\lib\site-packages (from ydata-profiling) (2.3.5)
# Requirement already satisfied: minify-html>=0.15.0 in d:\machine learning\myenv\lib\site-packages (from ydata-profiling) (0.18.1)
# Requirement already satisfied: filetype>=1.0.0 in d:\machine learning\myenv\lib\site-packages (from ydata-profiling) (1.2.0)
# Collecting phik<0.13,>=0.12.5 (from ydata-profiling)
#   Using cached phik-0.12.5-cp313-cp313-win_amd64.whl.metadata (5.6 kB)
# Requirement already satisfied: requests<3,>=2.32.0 in d:\machine learning\myenv\lib\site-packages (from ydata-profiling) (2.32.5)
# Requirement already satisfied: tqdm<5,>=4.66.3 in d:\machine learning\myenv\lib\site-packages (from ydata-profiling) (4.67.3)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in d:\machine learning\myenv\lib\site-packages (from ydata-profiling) (0.13.2)
# Requirement already satisfied: multimethod<2,>=1.4 in d:\machine learning\myenv\lib\site-packages (from ydata-profiling) (1.12)
# Collecting statsmodels<1,>=0.13.2 (from ydata-profiling)
#   Using cached statsmodels-0.14.6-cp313-cp313-win_amd64.whl.metadata (9.8 kB)
# Requirement already satisfied: typeguard<5,>=4 in d:\machine learning\myenv\lib\site-packages (from ydata-profiling) (4.4.4)
# Collecting imagehash==4.3.2 (from ydata-profiling)
#   Using cached ImageHash-4.3.2-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting wordcloud>=1.9.4 (from ydata-profiling)
#   Using cached wordcloud-1.9.6-cp313-cp313-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: dacite<2,>=1.9 in d:\machine learning\myenv\lib\site-packages (from ydata-profiling) (1.9.2)
# Collecting numba<0.63,>=0.60 (from ydata-profiling)
#   Using cached numba-0.62.1-cp313-cp313-win_amd64.whl.metadata (2.9 kB)
# Requirement already satisfied: PyWavelets in d:\machine learning\myenv\lib\site-packages (from imagehash==4.3.2->ydata-profiling) (1.9.0)
# Requirement already satisfied: pillow in d:\machine learning\myenv\lib\site-packages (from imagehash==4.3.2->ydata-profiling) (12.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\machine learning\myenv\lib\site-packages (from jinja2<3.2,>=3.1.6->ydata-profiling) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in d:\machine learning\myenv\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in d:\machine learning\myenv\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\machine learning\myenv\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\machine learning\myenv\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in d:\machine learning\myenv\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (26.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\machine learning\myenv\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in d:\machine learning\myenv\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.46,>=0.45.0dev0 in d:\machine learning\myenv\lib\site-packages (from numba<0.63,>=0.60->ydata-profiling) (0.45.1)
# Requirement already satisfied: pytz>=2020.1 in d:\machine learning\myenv\lib\site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\machine learning\myenv\lib\site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling) (2025.3)
# Requirement already satisfied: joblib>=0.14.1 in d:\machine learning\myenv\lib\site-packages (from phik<0.13,>=0.12.5->ydata-profiling) (1.5.3)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\machine learning\myenv\lib\site-packages (from pydantic<3,>=2->ydata-profiling) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in d:\machine learning\myenv\lib\site-packages (from pydantic<3,>=2->ydata-profiling) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in d:\machine learning\myenv\lib\site-packages (from pydantic<3,>=2->ydata-profiling) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in d:\machine learning\myenv\lib\site-packages (from pydantic<3,>=2->ydata-profiling) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\machine learning\myenv\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\machine learning\myenv\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\machine learning\myenv\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in d:\machine learning\myenv\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (2026.1.4)
# Requirement already satisfied: patsy>=0.5.6 in d:\machine learning\myenv\lib\site-packages (from statsmodels<1,>=0.13.2->ydata-profiling) (1.0.2)
# Requirement already satisfied: colorama in d:\machine learning\myenv\lib\site-packages (from tqdm<5,>=4.66.3->ydata-profiling) (0.4.6)
# Requirement already satisfied: attrs>=19.3.0 in d:\machine learning\myenv\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (25.4.0)
# Requirement already satisfied: networkx>=2.4 in d:\machine learning\myenv\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (3.6.1)
# Requirement already satisfied: puremagic in d:\machine learning\myenv\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (1.30)
# Requirement already satisfied: six>=1.5 in d:\machine learning\myenv\lib\site-packages (from python-dateutil>=2.7->matplotlib<=3.10,>=3.5->ydata-profiling) (1.17.0)
# Using cached ydata_profiling-4.18.1-py2.py3-none-any.whl (400 kB)
# Using cached ImageHash-4.3.2-py2.py3-none-any.whl (296 kB)
# Using cached matplotlib-3.10.0-cp313-cp313-win_amd64.whl (8.0 MB)
# Using cached numba-0.62.1-cp313-cp313-win_amd64.whl (2.7 MB)
# Using cached phik-0.12.5-cp313-cp313-win_amd64.whl (678 kB)
# Using cached statsmodels-0.14.6-cp313-cp313-win_amd64.whl (9.5 MB)
# Using cached visions-0.8.1-py3-none-any.whl (105 kB)
# Using cached wordcloud-1.9.6-cp313-cp313-win_amd64.whl (306 kB)
# Installing collected packages: numba, matplotlib, imagehash, wordcloud, visions, statsmodels, phik, ydata-profiling
#
#    ---------------------------------------- 0/8 [numba]
#    ---------------------------------------- 0/8 [numba]
#    ---------------------------------------- 0/8 [numba]
#    ---------------------------------------- 0/8 [numba]
#    ---------------------------------------- 0/8 [numba]
#    ---------------------------------------- 0/8 [numba]
#    ---------------------------------------- 0/8 [numba]
#    ---------------------------------------- 0/8 [numba]
#    ---------------------------------------- 0/8 [numba]
#    ---------------------------------------- 0/8 [numba]
#    ---------------------------------------- 0/8 [numba]
#    ---------------------------------------- 0/8 [numba]
#    ---------------------------------------- 0/8 [numba]
#    ---------------------------------------- 0/8 [numba]
#    ---------------------------------------- 0/8 [numba]
#    ---------------------------------------- 0/8 [numba]
#    ---------------------------------------- 0/8 [numba]
#    ---------------------------------------- 0/8 [numba]
#    ---------------------------------------- 0/8 [numba]
#    ---------------------------------------- 0/8 [numba]
#    ---------------------------------------- 0/8 [numba]
#    ---------------------------------------- 0/8 [numba]
#    ---------------------------------------- 0/8 [numba]
#    ---------------------------------------- 0/8 [numba]
#    ---------------------------------------- 0/8 [numba]
#    ---------------------------------------- 0/8 [numba]
#    ---------------------------------------- 0/8 [numba]
#    ---------------------------------------- 0/8 [numba]
#    ---------------------------------------- 0/8 [numba]
#    ---------------------------------------- 0/8 [numba]
#    ---------------------------------------- 0/8 [numba]
#    ---------------------------------------- 0/8 [numba]
#    ---------------------------------------- 0/8 [numba]
#    ---------------------------------------- 0/8 [numba]
#    ---------------------------------------- 0/8 [numba]
#    ---------------------------------------- 0/8 [numba]
#    ---------------------------------------- 0/8 [numba]
#    ---------------------------------------- 0/8 [numba]
#    ---------------------------------------- 0/8 [numba]
#    ---------------------------------------- 0/8 [numba]
#    ---------------------------------------- 0/8 [numba]
#    ---------------------------------------- 0/8 [numba]
#    ---------------------------------------- 0/8 [numba]
#    ---------------------------------------- 0/8 [numba]
#    ---------------------------------------- 0/8 [numba]
#    ---------------------------------------- 0/8 [numba]
#    ---------------------------------------- 0/8 [numba]
#    ---------------------------------------- 0/8 [numba]
#    ---------------------------------------- 0/8 [numba]
#    ---------------------------------------- 0/8 [numba]
#    ---------------------------------------- 0/8 [numba]
#    ---------------------------------------- 0/8 [numba]
#    ---------------------------------------- 0/8 [numba]
#    ---------------------------------------- 0/8 [numba]
#    ---------------------------------------- 0/8 [numba]
#    ---------------------------------------- 0/8 [numba]
#    ---------------------------------------- 0/8 [numba]
#    ---------------------------------------- 0/8 [numba]
#    ---------------------------------------- 0/8 [numba]
#    ---------------------------------------- 0/8 [numba]
#    ---------------------------------------- 0/8 [numba]
#    ---------------------------------------- 0/8 [numba]
#    ---------------------------------------- 0/8 [numba]
#    ---------------------------------------- 0/8 [numba]
#   Attempting uninstall: matplotlib
#    ---------------------------------------- 0/8 [numba]
#     Found existing installation: matplotlib 3.10.8
#    ---------------------------------------- 0/8 [numba]
#    ----- ---------------------------------- 1/8 [matplotlib]
#     Uninstalling matplotlib-3.10.8:
#    ----- ---------------------------------- 1/8 [matplotlib]
#    ----- ---------------------------------- 1/8 [matplotlib]
#    ----- ---------------------------------- 1/8 [matplotlib]
#    ----- ---------------------------------- 1/8 [matplotlib]
#       Successfully uninstalled matplotlib-3.10.8
#    ----- ---------------------------------- 1/8 [matplotlib]
#    ----- ---------------------------------- 1/8 [matplotlib]
#    ----- ---------------------------------- 1/8 [matplotlib]
#    ----- ---------------------------------- 1/8 [matplotlib]
#    ----- ---------------------------------- 1/8 [matplotlib]
#    ----- ---------------------------------- 1/8 [matplotlib]
#    ----- ---------------------------------- 1/8 [matplotlib]
#    ----- ---------------------------------- 1/8 [matplotlib]
#    ----- ---------------------------------- 1/8 [matplotlib]
#    ----- ---------------------------------- 1/8 [matplotlib]
#    ----- ---------------------------------- 1/8 [matplotlib]
#    ----- ---------------------------------- 1/8 [matplotlib]
#    ----- ---------------------------------- 1/8 [matplotlib]
#    ----- ---------------------------------- 1/8 [matplotlib]
#    ----- ---------------------------------- 1/8 [matplotlib]
#    ----- ---------------------------------- 1/8 [matplotlib]
#    ----- ---------------------------------- 1/8 [matplotlib]
#    ----- ---------------------------------- 1/8 [matplotlib]
#    ----- ---------------------------------- 1/8 [matplotlib]
#    ----- ---------------------------------- 1/8 [matplotlib]
#    ----- ---------------------------------- 1/8 [matplotlib]
#    ----- ---------------------------------- 1/8 [matplotlib]
#    ----- ---------------------------------- 1/8 [matplotlib]
#    ----- ---------------------------------- 1/8 [matplotlib]
#    ----- ---------------------------------- 1/8 [matplotlib]
#    ----- ---------------------------------- 1/8 [matplotlib]
#    ----- ---------------------------------- 1/8 [matplotlib]
#    ----- ---------------------------------- 1/8 [matplotlib]
#    ----- ---------------------------------- 1/8 [matplotlib]
#    ----- ---------------------------------- 1/8 [matplotlib]
#    ----- ---------------------------------- 1/8 [matplotlib]
#    ----- ---------------------------------- 1/8 [matplotlib]
#    ----- ---------------------------------- 1/8 [matplotlib]
#    ----- ---------------------------------- 1/8 [matplotlib]
#    ----- ---------------------------------- 1/8 [matplotlib]
#    ----- ---------------------------------- 1/8 [matplotlib]
#    --------------- ------------------------ 3/8 [wordcloud]
#    -------------------- ------------------- 4/8 [visions]
#    -------------------- ------------------- 4/8 [visions]
#    -------------------- ------------------- 4/8 [visions]
#    -------------------- ------------------- 4/8 [visions]
#    -------------------- ------------------- 4/8 [visions]
#    -------------------- ------------------- 4/8 [visions]
#    -------------------- ------------------- 4/8 [visions]
#    -------------------- ------------------- 4/8 [visions]
#    -------------------- ------------------- 4/8 [visions]
#    ------------------------- -------------- 5/8 [statsmodels]
#    ------------------------- -------------- 5/8 [statsmodels]
#    ------------------------- -------------- 5/8 [statsmodels]
#    ------------------------- -------------- 5/8 [statsmodels]
#    ------------------------- -------------- 5/8 [statsmodels]
#    ------------------------- -------------- 5/8 [statsmodels]
#    ------------------------- -------------- 5/8 [statsmodels]
#    ------------------------- -------------- 5/8 [statsmodels]
#    ------------------------- -------------- 5/8 [statsmodels]
#    ------------------------- -------------- 5/8 [statsmodels]
#    ------------------------- -------------- 5/8 [statsmodels]
#    ------------------------- -------------- 5/8 [statsmodels]
#    ------------------------- -------------- 5/8 [statsmodels]
#    ------------------------- -------------- 5/8 [statsmodels]
#    ------------------------- -------------- 5/8 [statsmodels]
#    ------------------------- -------------- 5/8 [statsmodels]
#    ------------------------- -------------- 5/8 [statsmodels]
#    ------------------------- -------------- 5/8 [statsmodels]
#    ------------------------- -------------- 5/8 [statsmodels]
#    ------------------------- -------------- 5/8 [statsmodels]
#    ------------------------- -------------- 5/8 [statsmodels]
#    ------------------------- -------------- 5/8 [statsmodels]
#    ------------------------- -------------- 5/8 [statsmodels]
#    ------------------------- -------------- 5/8 [statsmodels]
#    ------------------------- -------------- 5/8 [statsmodels]
#    ------------------------- -------------- 5/8 [statsmodels]
#    ------------------------- -------------- 5/8 [statsmodels]
#    ------------------------- -------------- 5/8 [statsmodels]
#    ------------------------- -------------- 5/8 [statsmodels]
#    ------------------------- -------------- 5/8 [statsmodels]
#    ------------------------- -------------- 5/8 [statsmodels]
#    ------------------------- -------------- 5/8 [statsmodels]
#    ------------------------- -------------- 5/8 [statsmodels]
#    ------------------------- -------------- 5/8 [statsmodels]
#    ------------------------- -------------- 5/8 [statsmodels]
#    ------------------------- -------------- 5/8 [statsmodels]
#    ------------------------- -------------- 5/8 [statsmodels]
#    ------------------------- -------------- 5/8 [statsmodels]
#    ------------------------- -------------- 5/8 [statsmodels]
#    ------------------------- -------------- 5/8 [statsmodels]
#    ------------------------- -------------- 5/8 [statsmodels]
#    ------------------------- -------------- 5/8 [statsmodels]
#    ------------------------- -------------- 5/8 [statsmodels]
#    ------------------------- -------------- 5/8 [statsmodels]
#    ------------------------- -------------- 5/8 [statsmodels]
#    ------------------------- -------------- 5/8 [statsmodels]
#    ------------------------- -------------- 5/8 [statsmodels]
#    ------------------------- -------------- 5/8 [statsmodels]
#    ------------------------- -------------- 5/8 [statsmodels]
#    ------------------------- -------------- 5/8 [statsmodels]
#    ------------------------- -------------- 5/8 [statsmodels]
#    ------------------------- -------------- 5/8 [statsmodels]
#    ------------------------- -------------- 5/8 [statsmodels]
#    ------------------------- -------------- 5/8 [statsmodels]
#    ------------------------- -------------- 5/8 [statsmodels]
#    ------------------------- -------------- 5/8 [statsmodels]
#    ------------------------- -------------- 5/8 [statsmodels]
#    ------------------------- -------------- 5/8 [statsmodels]
#    ------------------------- -------------- 5/8 [statsmodels]
#    ------------------------- -------------- 5/8 [statsmodels]
#    ------------------------- -------------- 5/8 [statsmodels]
#    ------------------------- -------------- 5/8 [statsmodels]
#    ------------------------- -------------- 5/8 [statsmodels]
#    ------------------------- -------------- 5/8 [statsmodels]
#    ------------------------- -------------- 5/8 [statsmodels]
#    ------------------------- -------------- 5/8 [statsmodels]
#    ------------------------- -------------- 5/8 [statsmodels]
#    ------------------------- -------------- 5/8 [statsmodels]
#    ------------------------- -------------- 5/8 [statsmodels]
#    ------------------------- -------------- 5/8 [statsmodels]
#    ------------------------- -------------- 5/8 [statsmodels]
#    ------------------------- -------------- 5/8 [statsmodels]
#    ------------------------- -------------- 5/8 [statsmodels]
#    ------------------------- -------------- 5/8 [statsmodels]
#    ------------------------- -------------- 5/8 [statsmodels]
#    ------------------------- -------------- 5/8 [statsmodels]
#    ------------------------- -------------- 5/8 [statsmodels]
#    ------------------------- -------------- 5/8 [statsmodels]
#    ------------------------- -------------- 5/8 [statsmodels]
#    ------------------------------ --------- 6/8 [phik]
#    ----------------------------------- ---- 7/8 [ydata-profiling]
#    ----------------------------------- ---- 7/8 [ydata-profiling]
#    ----------------------------------- ---- 7/8 [ydata-profiling]
#    ----------------------------------- ---- 7/8 [ydata-profiling]
#    ----------------------------------- ---- 7/8 [ydata-profiling]
#    ----------------------------------- ---- 7/8 [ydata-profiling]
#    ----------------------------------- ---- 7/8 [ydata-profiling]
#    ----------------------------------- ---- 7/8 [ydata-profiling]
#    ----------------------------------- ---- 7/8 [ydata-profiling]
#    ----------------------------------- ---- 7/8 [ydata-profiling]
#    ----------------------------------- ---- 7/8 [ydata-profiling]
#    ----------------------------------- ---- 7/8 [ydata-profiling]
#    ----------------------------------- ---- 7/8 [ydata-profiling]
#    ----------------------------------- ---- 7/8 [ydata-profiling]
#    ---------------------------------------- 8/8 [ydata-profiling]
#
# Successfully installed imagehash-4.3.2 matplotlib-3.10.0 numba-0.62.1 phik-0.12.5 statsmodels-0.14.6 visions-0.8.1 wordcloud-1.9.6 ydata-profiling-4.18.1
# WARNING: Ignoring invalid distribution ~andas (D:\machine learning\myenv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~andas (D:\machine learning\myenv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~andas (D:\machine learning\myenv\Lib\site-packages)
#
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from ydata_profiling import ProfileReport

# %%
import pandas as pd

# %%
df = pd.read_csv('train.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  ...  Cabin Embarked
# 0            1         0  ...    NaN        S
# 1            2         1  ...    C85        C
# 2            3         1  ...    NaN        S
# 3            4         1  ...   C123        S
# 4            5         0  ...    NaN        S
#
# [5 rows x 12 columns]

# %%
prof = ProfileReport(df)
prof.to_file(output_file='report.html')
# Out:
# Summarize dataset:  29%|▎| 5/17 [00:00<00:00, 44.05it/
# 100%|████████████████| 12/12 [00:00<00:00, 467.48it/s]
# Summarize dataset: 100%|█| 47/47 [00:02<00:00, 18.40it
# Generate report structure: 100%|█| 1/1 [00:02<00:00,
# Render HTML: 100%|██████| 1/1 [00:00<00:00,  1.32it/s]
# Export report to file: 100%|█| 1/1 [00:00<00:00, 71.47
